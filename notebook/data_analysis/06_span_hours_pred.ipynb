# %%
# %%time
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import sys
from dataclasses import dataclass
from pathlib import Path

import pandas as pd
from dotenv import load_dotenv


@dataclass
class Config:
    project_dir: Path = Path("../../")
    model_dir: Path = project_dir / "models"
    outputs_dir: Path = project_dir / "outputs"
    results_dir: Path = project_dir / "results"
    results_agg_dir: Path = results_dir / "agg"
    results_figs_dir: Path = results_dir / "figs"
    data_dir: Path = project_dir / "data"
    raw_dir: Path = data_dir / "raw"
    interim_dir: Path = data_dir / "interim"
    processed_dir: Path = data_dir / "processed"


config = Config()
sys.path.append(str(config.project_dir.resolve()))
load_dotenv()
# Out:
# CPU times: user 465 ms, sys: 103 ms, total: 568 ms
# Wall time: 828 ms
# True

# %%
df_order_info_details = pd.read_csv(config.processed_dir / "order_info_details.csv")
df_reviews = pd.read_csv(
    config.interim_dir
    / "olist_order_reviews_translated_label_review_categories_merged.csv",
)
df_reviews_last = df_reviews.groupby("order_id").last().reset_index()
df_order_info_details_reviews_merged = pd.merge(
    df_order_info_details, df_reviews_last, on="order_id", how="left"
)
assert df_order_info_details_reviews_merged.shape[0] == df_order_info_details.shape[0]
for col in [
    "order_purchase_timestamp",
    "order_approved_at",
    "order_delivered_carrier_date",
    "order_delivered_customer_date",
    "order_estimated_delivery_date",
    "shipping_limit_date",
]:
    df_order_info_details_reviews_merged[col] = pd.to_datetime(
        df_order_info_details_reviews_merged[col],
        format="mixed",
    )
df_review_no_null = df_order_info_details_reviews_merged.dropna(
    subset=["review_comment_message_en"]
)
print(f"df_review_no_null.shape: {df_review_no_null.shape}")

df_target = (
    df_review_no_null.query(
        "review_categories_str_modified in ['Delivery_Issue','Delivery_Praise'] "
    )
    .query("customer_state in ['SP','RJ']")
    .dropna(subset=["order_delivered_customer_span_hours_from_carrier"])
)
df_target["is_same_state"] = (
    df_target["customer_state"] == df_target["seller_state"]
).astype(int)
df_target["is_same_city"] = (
    df_target["customer_city"] == df_target["seller_city"]
).astype(int)
df_target["freight_ratio"] = (
    df_target["sum_freight"] / df_target["sum_price_freight_by_order"]
)

y, x = (
    df_target["order_delivered_customer_span_hours_from_carrier"],
    df_target[
        [
            "order_purchase_month",
            "customer_city",
            "customer_state",
            "sum_price",
            "sum_freight",
            "sum_price_freight_by_order",
            "product_count",
            "seller_count",
            "product_photos_qty",
            "sum_product_weight_g",
            "sum_product_volume_cm3",
            "product_length_cm",
            "product_height_cm",
            "product_width_cm",
            "seller_city_count",
            "seller_state_count",
            "product_category_name_english",
            "seller_city",
            "seller_state",
            "distance_between_customer_and_seller",
            "is_same_state",
            "is_same_city",
            "total_payment_value",
            "payment_type_count",
            "most_common_payment_type",
            "highest_value_payment_type",
            "highest_payment_value",
        ]
    ],
)
categorical_features = [
    "order_purchase_month",
    "customer_city",
    "customer_state",
    "product_category_name_english",
    "seller_city",
    "seller_state",
    "most_common_payment_type",
    "highest_value_payment_type",
]
param_dist = {
    "num_leaves": [31, 50, 100, 200],
    "learning_rate": [0.01, 0.05, 0.1],
    "n_estimators": [100, 200, 500, 1000],
    "feature_fraction": [0.7, 0.8, 0.9, 1.0],
    "min_child_samples": [10, 20, 30, 50],
    "max_depth": [-1, 5, 10, 20],
    "reg_alpha": [0, 0.1, 0.5, 1.0],
    "reg_lambda": [0, 0.1, 0.5, 1.0],
    "bagging_fraction": [0.8, 0.9, 1.0],
    "bagging_freq": [0, 5, 10],
}
# Out:
# df_review_no_null.shape: (40818, 90)

# %%
from src.trainer.train_lgbm import LGBMTrainer

lgbm_trainer = LGBMTrainer(
    x=x, y=y, categorical_features=categorical_features, params=param_dist
)
lgbm_trainer.train(best_model_output_path=config.model_dir / "best_lgbm_model.pickle")
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# /Users/shim-kojio/Documents/ey_sat_lab/src/trainer/train_lgbm.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.x[col] = self.x[col].astype("category")
# /Users/shim-kojio/Documents/ey_sat_lab/src/trainer/train_lgbm.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.x[col] = self.x[col].astype("category")
# /Users/shim-kojio/Documents/ey_sat_lab/src/trainer/train_lgbm.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.x[col] = self.x[col].astype("category")
# /Users/shim-kojio/Documents/ey_sat_lab/src/trainer/train_lgbm.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.x[col] = self.x[col].astype("category")
# /Users/shim-kojio/Documents/ey_sat_lab/src/trainer/train_lgbm.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.x[col] = self.x[col].astype("category")
# /Users/shim-kojio/Documents/ey_sat_lab/src/trainer/train_lgbm.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.x[col] = self.x[col].astype("category")
# /Users/shim-kojio/Documents/ey_sat_lab/src/trainer/train_lgbm.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.x[col] = self.x[col].astype("category")
# /Users/shim-kojio/Documents/ey_sat_lab/src/trainer/train_lgbm.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.x[col] = self.x[col].astype("category")
# [CV] END bagging_fraction=0.8, bagging_freq=10, feature_fraction=0.8, learning_rate=0.1, max_depth=20, min_child_samples=10, n_estimators=200, num_leaves=100, reg_alpha=0.1, reg_lambda=0.5; total time=  21.7s
# [CV] END bagging_fraction=0.8, bagging_freq=10, feature_fraction=0.8, learning_rate=0.1, max_depth=20, min_child_samples=10, n_estimators=200, num_leaves=100, reg_alpha=0.1, reg_lambda=0.5; total time=  21.9s
# [CV] END bagging_fraction=0.8, bagging_freq=10, feature_fraction=0.8, learning_rate=0.1, max_depth=20, min_child_samples=10, n_estimators=200, num_leaves=100, reg_alpha=0.1, reg_lambda=0.5; total time=  22.0s
# [CV] END bagging_fraction=0.8, bagging_freq=10, feature_fraction=0.8, learning_rate=0.1, max_depth=20, min_child_samples=10, n_estimators=200, num_leaves=100, reg_alpha=0.1, reg_lambda=0.5; total time=  22.1s
# [CV] END bagging_fraction=0.8, bagging_freq=10, feature_fraction=0.8, learning_rate=0.1, max_depth=20, min_child_samples=10, n_estimators=200, num_leaves=100, reg_alpha=0.1, reg_lambda=0.5; total time=  22.2s
# [CV] END bagging_fraction=0.8, bagging_freq=10, feature_fraction=0.9, learning_rate=0.1, max_depth=-1, min_child_samples=50, n_estimators=200, num_leaves=50, reg_alpha=1.0, reg_lambda=0; total time=  10.0s
# [CV] END bagging_fraction=0.8, bagging_freq=10, feature_fraction=0.9, learning_rate=0.1, max_depth=-1, min_child_samples=50, n_estimators=200, num_leaves=50, reg_alpha=1.0, reg_lambda=0; total time=  10.2s
# [CV] END bagging_fraction=0.8, bagging_freq=10, feature_fraction=0.9, learning_rate=0.1, max_depth=-1, min_child_samples=50, n_estimators=200, num_leaves=50, reg_alpha=1.0, reg_lambda=0; total time=  11.6s
# [CV] END bagging_fraction=1.0, bagging_freq=5, feature_fraction=0.8, learning_rate=0.1, max_depth=5, min_child_samples=20, n_estimators=100, num_leaves=31, reg_alpha=1.0, reg_lambda=0.5; total time=   2.4s
# [CV] END bagging_fraction=1.0, bagging_freq=5, feature_fraction=0.8, learning_rate=0.1, max_depth=5, min_child_samples=20, n_estimators=100, num_leaves=31, reg_alpha=1.0, reg_lambda=0.5; total time=   1.8s
# [CV] END bagging_fraction=1.0, bagging_freq=5, feature_fraction=0.8, learning_rate=0.1, max_depth=5, min_child_samples=20, n_estimators=100, num_leaves=31, reg_alpha=1.0, reg_lambda=0.5; total time=   2.1s
# [CV] END bagging_fraction=1.0, bagging_freq=5, feature_fraction=0.8, learning_rate=0.1, max_depth=5, min_child_samples=20, n_estimators=100, num_leaves=31, reg_alpha=1.0, reg_lambda=0.5; total time=   2.6s
# [CV] END bagging_fraction=0.8, bagging_freq=10, feature_fraction=0.9, learning_rate=0.1, max_depth=-1, min_child_samples=50, n_estimators=200, num_leaves=50, reg_alpha=1.0, reg_lambda=0; total time=  11.2s
# [CV] END bagging_fraction=0.8, bagging_freq=10, feature_fraction=0.9, learning_rate=0.1, max_depth=-1, min_child_samples=50, n_estimators=200, num_leaves=50, reg_alpha=1.0, reg_lambda=0; total time=  11.2s
# [CV] END bagging_fraction=1.0, bagging_freq=5, feature_fraction=0.8, learning_rate=0.1, max_depth=5, min_child_samples=20, n_estimators=100, num_leaves=31, reg_alpha=1.0, reg_lambda=0.5; total time=   2.0s
# [CV] END bagging_fraction=0.9, bagging_freq=10, feature_fraction=0.8, learning_rate=0.01, max_depth=5, min_child_samples=10, n_estimators=200, num_leaves=100, reg_alpha=0.5, reg_lambda=0.5; total time=   6.2s
# [CV] END bagging_fraction=0.9, bagging_freq=10, feature_fraction=0.8, learning_rate=0.01, max_depth=5, min_child_samples=10, n_estimators=200, num_leaves=100, reg_alpha=0.5, reg_lambda=0.5; total time=   6.2s
# [CV] END bagging_fraction=0.9, bagging_freq=10, feature_fraction=0.8, learning_rate=0.01, max_depth=5, min_child_samples=10, n_estimators=200, num_leaves=100, reg_alpha=0.5, reg_lambda=0.5; total time=   6.0s
# [CV] END bagging_fraction=0.9, bagging_freq=10, feature_fraction=0.8, learning_rate=0.01, max_depth=5, min_child_samples=10, n_estimators=200, num_leaves=100, reg_alpha=0.5, reg_lambda=0.5; total time=   4.6s
# [CV] END bagging_fraction=0.9, bagging_freq=10, feature_fraction=0.8, learning_rate=0.01, max_depth=5, min_child_samples=10, n_estimators=200, num_leaves=100, reg_alpha=0.5, reg_lambda=0.5; total time=   4.7s
# [CV] END bagging_fraction=0.8, bagging_freq=10, feature_fraction=0.8, learning_rate=0.1, max_depth=5, min_child_samples=10, n_estimators=200, num_leaves=31, reg_alpha=0.1, reg_lambda=1.0; total time=   4.7s
# [CV] END bagging_fraction=0.8, bagging_freq=10, feature_fraction=0.8, learning_rate=0.1, max_depth=5, min_child_samples=10, n_estimators=200, num_leaves=31, reg_alpha=0.1, reg_lambda=1.0; total time=   8.1s
# [CV] END bagging_fraction=0.8, bagging_freq=10, feature_fraction=0.8, learning_rate=0.1, max_depth=5, min_child_samples=10, n_estimators=200, num_leaves=31, reg_alpha=0.1, reg_lambda=1.0; total time=   8.3s
# [CV] END bagging_fraction=0.8, bagging_freq=10, feature_fraction=0.8, learning_rate=0.1, max_depth=5, min_child_samples=10, n_estimators=200, num_leaves=31, reg_alpha=0.1, reg_lambda=1.0; total time=   7.5s
# [CV] END bagging_fraction=0.8, bagging_freq=10, feature_fraction=0.8, learning_rate=0.1, max_depth=5, min_child_samples=10, n_estimators=200, num_leaves=31, reg_alpha=0.1, reg_lambda=1.0; total time=   4.9s
# [CV] END bagging_fraction=0.8, bagging_freq=10, feature_fraction=1.0, learning_rate=0.1, max_depth=20, min_child_samples=20, n_estimators=500, num_leaves=200, reg_alpha=0, reg_lambda=1.0; total time= 1.3min
# [CV] END bagging_fraction=0.8, bagging_freq=10, feature_fraction=1.0, learning_rate=0.1, max_depth=20, min_child_samples=20, n_estimators=500, num_leaves=200, reg_alpha=0, reg_lambda=1.0; total time= 1.3min
# [CV] END bagging_fraction=0.8, bagging_freq=10, feature_fraction=1.0, learning_rate=0.1, max_depth=20, min_child_samples=20, n_estimators=500, num_leaves=200, reg_alpha=0, reg_lambda=1.0; total time= 1.4min
# [CV] END bagging_fraction=0.9, bagging_freq=5, feature_fraction=0.7, learning_rate=0.1, max_depth=20, min_child_samples=10, n_estimators=100, num_leaves=50, reg_alpha=0.1, reg_lambda=0; total time=   9.1s
# [CV] END bagging_fraction=0.9, bagging_freq=5, feature_fraction=0.7, learning_rate=0.1, max_depth=20, min_child_samples=10, n_estimators=100, num_leaves=50, reg_alpha=0.1, reg_lambda=0; total time=   5.1s
# [CV] END bagging_fraction=0.9, bagging_freq=5, feature_fraction=0.7, learning_rate=0.1, max_depth=20, min_child_samples=10, n_estimators=100, num_leaves=50, reg_alpha=0.1, reg_lambda=0; total time=   5.7s
# [CV] END bagging_fraction=0.8, bagging_freq=10, feature_fraction=1.0, learning_rate=0.1, max_depth=20, min_child_samples=20, n_estimators=500, num_leaves=200, reg_alpha=0, reg_lambda=1.0; total time= 1.4min
# [CV] END bagging_fraction=0.8, bagging_freq=10, feature_fraction=1.0, learning_rate=0.1, max_depth=20, min_child_samples=20, n_estimators=500, num_leaves=200, reg_alpha=0, reg_lambda=1.0; total time= 1.4min
# [CV] END bagging_fraction=0.9, bagging_freq=5, feature_fraction=0.7, learning_rate=0.1, max_depth=20, min_child_samples=10, n_estimators=100, num_leaves=50, reg_alpha=0.1, reg_lambda=0; total time=   4.9s
# [CV] END bagging_fraction=0.9, bagging_freq=5, feature_fraction=0.7, learning_rate=0.1, max_depth=20, min_child_samples=10, n_estimators=100, num_leaves=50, reg_alpha=0.1, reg_lambda=0; total time=   5.3s
# [CV] END bagging_fraction=0.8, bagging_freq=5, feature_fraction=0.7, learning_rate=0.05, max_depth=5, min_child_samples=30, n_estimators=200, num_leaves=100, reg_alpha=0.1, reg_lambda=0.5; total time=   3.5s
# [CV] END bagging_fraction=0.8, bagging_freq=5, feature_fraction=0.7, learning_rate=0.05, max_depth=5, min_child_samples=30, n_estimators=200, num_leaves=100, reg_alpha=0.1, reg_lambda=0.5; total time=   3.8s
# [CV] END bagging_fraction=0.8, bagging_freq=5, feature_fraction=0.7, learning_rate=0.05, max_depth=5, min_child_samples=30, n_estimators=200, num_leaves=100, reg_alpha=0.1, reg_lambda=0.5; total time=   4.5s
# [CV] END bagging_fraction=0.8, bagging_freq=5, feature_fraction=0.7, learning_rate=0.05, max_depth=5, min_child_samples=30, n_estimators=200, num_leaves=100, reg_alpha=0.1, reg_lambda=0.5; total time=   5.1s
# [CV] END bagging_fraction=0.8, bagging_freq=10, feature_fraction=0.7, learning_rate=0.1, max_depth=20, min_child_samples=30, n_estimators=500, num_leaves=200, reg_alpha=1.0, reg_lambda=0; total time=  54.9s
# [CV] END bagging_fraction=0.8, bagging_freq=5, feature_fraction=0.7, learning_rate=0.05, max_depth=5, min_child_samples=30, n_estimators=200, num_leaves=100, reg_alpha=0.1, reg_lambda=0.5; total time=   5.8s
# [CV] END bagging_fraction=0.8, bagging_freq=10, feature_fraction=0.7, learning_rate=0.1, max_depth=20, min_child_samples=30, n_estimators=500, num_leaves=200, reg_alpha=1.0, reg_lambda=0; total time=  55.5s
# [CV] END bagging_fraction=0.8, bagging_freq=10, feature_fraction=0.7, learning_rate=0.1, max_depth=20, min_child_samples=30, n_estimators=500, num_leaves=200, reg_alpha=1.0, reg_lambda=0; total time=  55.1s
# [CV] END bagging_fraction=1.0, bagging_freq=10, feature_fraction=1.0, learning_rate=0.01, max_depth=-1, min_child_samples=20, n_estimators=200, num_leaves=31, reg_alpha=0.5, reg_lambda=0.5; total time=   5.9s
# [CV] END bagging_fraction=0.8, bagging_freq=10, feature_fraction=0.7, learning_rate=0.1, max_depth=20, min_child_samples=30, n_estimators=500, num_leaves=200, reg_alpha=1.0, reg_lambda=0; total time=  53.4s
# [CV] END bagging_fraction=0.8, bagging_freq=10, feature_fraction=0.7, learning_rate=0.1, max_depth=20, min_child_samples=30, n_estimators=500, num_leaves=200, reg_alpha=1.0, reg_lambda=0; total time=  53.9s
# [CV] END bagging_fraction=1.0, bagging_freq=10, feature_fraction=1.0, learning_rate=0.01, max_depth=-1, min_child_samples=20, n_estimators=200, num_leaves=31, reg_alpha=0.5, reg_lambda=0.5; total time=   6.3s
# [CV] END bagging_fraction=1.0, bagging_freq=10, feature_fraction=1.0, learning_rate=0.01, max_depth=-1, min_child_samples=20, n_estimators=200, num_leaves=31, reg_alpha=0.5, reg_lambda=0.5; total time=   6.9s
# [CV] END bagging_fraction=1.0, bagging_freq=10, feature_fraction=1.0, learning_rate=0.01, max_depth=-1, min_child_samples=20, n_estimators=200, num_leaves=31, reg_alpha=0.5, reg_lambda=0.5; total time=   7.0s
# [CV] END bagging_fraction=1.0, bagging_freq=10, feature_fraction=1.0, learning_rate=0.01, max_depth=-1, min_child_samples=20, n_estimators=200, num_leaves=31, reg_alpha=0.5, reg_lambda=0.5; total time=   7.0s
# [CV] END bagging_fraction=0.8, bagging_freq=10, feature_fraction=1.0, learning_rate=0.01, max_depth=10, min_child_samples=10, n_estimators=200, num_leaves=200, reg_alpha=0.5, reg_lambda=0.1; total time=  32.2s
# [CV] END bagging_fraction=0.8, bagging_freq=10, feature_fraction=1.0, learning_rate=0.01, max_depth=10, min_child_samples=10, n_estimators=200, num_leaves=200, reg_alpha=0.5, reg_lambda=0.1; total time=  32.0s
# [CV] END bagging_fraction=0.8, bagging_freq=10, feature_fraction=1.0, learning_rate=0.01, max_depth=10, min_child_samples=10, n_estimators=200, num_leaves=200, reg_alpha=0.5, reg_lambda=0.1; total time=  31.1s
# [CV] END bagging_fraction=0.8, bagging_freq=10, feature_fraction=1.0, learning_rate=0.01, max_depth=10, min_child_samples=10, n_estimators=200, num_leaves=200, reg_alpha=0.5, reg_lambda=0.1; total time=  33.3s
# [CV] END bagging_fraction=0.8, bagging_freq=10, feature_fraction=1.0, learning_rate=0.01, max_depth=10, min_child_samples=10, n_estimators=200, num_leaves=200, reg_alpha=0.5, reg_lambda=0.1; total time=  33.5s
# [CV] END bagging_fraction=1.0, bagging_freq=5, feature_fraction=0.9, learning_rate=0.05, max_depth=10, min_child_samples=10, n_estimators=200, num_leaves=50, reg_alpha=0.1, reg_lambda=1.0; total time=  12.1s
# [CV] END bagging_fraction=1.0, bagging_freq=5, feature_fraction=0.9, learning_rate=0.05, max_depth=10, min_child_samples=10, n_estimators=200, num_leaves=50, reg_alpha=0.1, reg_lambda=1.0; total time=  11.1s
# [CV] END bagging_fraction=1.0, bagging_freq=5, feature_fraction=0.9, learning_rate=0.05, max_depth=10, min_child_samples=10, n_estimators=200, num_leaves=50, reg_alpha=0.1, reg_lambda=1.0; total time=  11.3s
# [CV] END bagging_fraction=0.8, bagging_freq=5, feature_fraction=1.0, learning_rate=0.01, max_depth=5, min_child_samples=20, n_estimators=1000, num_leaves=31, reg_alpha=0.5, reg_lambda=0.5; total time=  24.3s
# [CV] END bagging_fraction=0.8, bagging_freq=5, feature_fraction=1.0, learning_rate=0.01, max_depth=5, min_child_samples=20, n_estimators=1000, num_leaves=31, reg_alpha=0.5, reg_lambda=0.5; total time=  25.1s
# [CV] END bagging_fraction=0.8, bagging_freq=5, feature_fraction=1.0, learning_rate=0.01, max_depth=5, min_child_samples=20, n_estimators=1000, num_leaves=31, reg_alpha=0.5, reg_lambda=0.5; total time=  27.8s
# [CV] END bagging_fraction=0.8, bagging_freq=5, feature_fraction=1.0, learning_rate=0.01, max_depth=5, min_child_samples=20, n_estimators=1000, num_leaves=31, reg_alpha=0.5, reg_lambda=0.5; total time=  23.8s
# [CV] END bagging_fraction=1.0, bagging_freq=5, feature_fraction=0.9, learning_rate=0.05, max_depth=10, min_child_samples=10, n_estimators=200, num_leaves=50, reg_alpha=0.1, reg_lambda=1.0; total time=  11.5s
# [CV] END bagging_fraction=0.8, bagging_freq=5, feature_fraction=1.0, learning_rate=0.01, max_depth=5, min_child_samples=20, n_estimators=1000, num_leaves=31, reg_alpha=0.5, reg_lambda=0.5; total time=  26.0s
# [CV] END bagging_fraction=1.0, bagging_freq=5, feature_fraction=0.9, learning_rate=0.05, max_depth=10, min_child_samples=10, n_estimators=200, num_leaves=50, reg_alpha=0.1, reg_lambda=1.0; total time=  12.9s
# [CV] END bagging_fraction=0.9, bagging_freq=0, feature_fraction=0.9, learning_rate=0.01, max_depth=20, min_child_samples=10, n_estimators=200, num_leaves=100, reg_alpha=0, reg_lambda=1.0; total time=  22.3s
# [CV] END bagging_fraction=0.9, bagging_freq=0, feature_fraction=0.9, learning_rate=0.01, max_depth=20, min_child_samples=10, n_estimators=200, num_leaves=100, reg_alpha=0, reg_lambda=1.0; total time=  22.6s
# [CV] END bagging_fraction=0.9, bagging_freq=0, feature_fraction=0.9, learning_rate=0.01, max_depth=20, min_child_samples=10, n_estimators=200, num_leaves=100, reg_alpha=0, reg_lambda=1.0; total time=  22.8s
# [CV] END bagging_fraction=1.0, bagging_freq=5, feature_fraction=1.0, learning_rate=0.05, max_depth=20, min_child_samples=20, n_estimators=200, num_leaves=200, reg_alpha=0.1, reg_lambda=0; total time=  38.5s
# [CV] END bagging_fraction=1.0, bagging_freq=5, feature_fraction=1.0, learning_rate=0.05, max_depth=20, min_child_samples=20, n_estimators=200, num_leaves=200, reg_alpha=0.1, reg_lambda=0; total time=  39.8s
# [CV] END bagging_fraction=1.0, bagging_freq=5, feature_fraction=1.0, learning_rate=0.05, max_depth=20, min_child_samples=20, n_estimators=200, num_leaves=200, reg_alpha=0.1, reg_lambda=0; total time=  36.8s
# [CV] END bagging_fraction=1.0, bagging_freq=5, feature_fraction=1.0, learning_rate=0.05, max_depth=20, min_child_samples=20, n_estimators=200, num_leaves=200, reg_alpha=0.1, reg_lambda=0; total time=  37.4s
# [CV] END bagging_fraction=0.9, bagging_freq=0, feature_fraction=1.0, learning_rate=0.05, max_depth=10, min_child_samples=50, n_estimators=200, num_leaves=100, reg_alpha=0.1, reg_lambda=1.0; total time=   8.2s
# [CV] END bagging_fraction=1.0, bagging_freq=5, feature_fraction=1.0, learning_rate=0.05, max_depth=20, min_child_samples=20, n_estimators=200, num_leaves=200, reg_alpha=0.1, reg_lambda=0; total time=  37.1s
# [CV] END bagging_fraction=0.9, bagging_freq=0, feature_fraction=1.0, learning_rate=0.05, max_depth=10, min_child_samples=50, n_estimators=200, num_leaves=100, reg_alpha=0.1, reg_lambda=1.0; total time=   7.7s
# [CV] END bagging_fraction=0.9, bagging_freq=0, feature_fraction=1.0, learning_rate=0.05, max_depth=10, min_child_samples=50, n_estimators=200, num_leaves=100, reg_alpha=0.1, reg_lambda=1.0; total time=   7.7s
# [CV] END bagging_fraction=0.9, bagging_freq=0, feature_fraction=1.0, learning_rate=0.05, max_depth=10, min_child_samples=50, n_estimators=200, num_leaves=100, reg_alpha=0.1, reg_lambda=1.0; total time=   8.1s
# [CV] END bagging_fraction=0.9, bagging_freq=0, feature_fraction=1.0, learning_rate=0.05, max_depth=10, min_child_samples=50, n_estimators=200, num_leaves=100, reg_alpha=0.1, reg_lambda=1.0; total time=   7.9s
# [CV] END bagging_fraction=0.9, bagging_freq=0, feature_fraction=0.9, learning_rate=0.01, max_depth=20, min_child_samples=10, n_estimators=200, num_leaves=100, reg_alpha=0, reg_lambda=1.0; total time=  18.6s
# [CV] END bagging_fraction=0.9, bagging_freq=0, feature_fraction=0.9, learning_rate=0.01, max_depth=20, min_child_samples=10, n_estimators=200, num_leaves=100, reg_alpha=0, reg_lambda=1.0; total time=  18.0s
# [CV] END bagging_fraction=0.8, bagging_freq=0, feature_fraction=1.0, learning_rate=0.05, max_depth=-1, min_child_samples=10, n_estimators=500, num_leaves=31, reg_alpha=0, reg_lambda=0.5; total time=  14.2s
# [CV] END bagging_fraction=0.9, bagging_freq=10, feature_fraction=0.9, learning_rate=0.05, max_depth=20, min_child_samples=30, n_estimators=500, num_leaves=50, reg_alpha=0.1, reg_lambda=1.0; total time=  22.4s
# [CV] END bagging_fraction=0.8, bagging_freq=0, feature_fraction=1.0, learning_rate=0.05, max_depth=-1, min_child_samples=10, n_estimators=500, num_leaves=31, reg_alpha=0, reg_lambda=0.5; total time=  16.2s
# [CV] END bagging_fraction=0.8, bagging_freq=0, feature_fraction=1.0, learning_rate=0.05, max_depth=-1, min_child_samples=10, n_estimators=500, num_leaves=31, reg_alpha=0, reg_lambda=0.5; total time=  14.5s
# [CV] END bagging_fraction=0.9, bagging_freq=10, feature_fraction=0.9, learning_rate=0.05, max_depth=20, min_child_samples=30, n_estimators=500, num_leaves=50, reg_alpha=0.1, reg_lambda=1.0; total time=  22.5s
# [CV] END bagging_fraction=0.9, bagging_freq=10, feature_fraction=0.9, learning_rate=0.05, max_depth=20, min_child_samples=30, n_estimators=500, num_leaves=50, reg_alpha=0.1, reg_lambda=1.0; total time=  24.7s
# [CV] END bagging_fraction=0.9, bagging_freq=10, feature_fraction=0.9, learning_rate=0.05, max_depth=20, min_child_samples=30, n_estimators=500, num_leaves=50, reg_alpha=0.1, reg_lambda=1.0; total time=  22.4s
# [CV] END bagging_fraction=0.9, bagging_freq=10, feature_fraction=0.9, learning_rate=0.05, max_depth=20, min_child_samples=30, n_estimators=500, num_leaves=50, reg_alpha=0.1, reg_lambda=1.0; total time=  22.7s
# [CV] END bagging_fraction=1.0, bagging_freq=0, feature_fraction=0.9, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=500, num_leaves=50, reg_alpha=0.1, reg_lambda=0.1; total time=   7.0s
# [CV] END bagging_fraction=1.0, bagging_freq=0, feature_fraction=0.9, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=500, num_leaves=50, reg_alpha=0.1, reg_lambda=0.1; total time=   7.0s
# [CV] END bagging_fraction=1.0, bagging_freq=0, feature_fraction=0.9, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=500, num_leaves=50, reg_alpha=0.1, reg_lambda=0.1; total time=   7.4s
# [CV] END bagging_fraction=1.0, bagging_freq=0, feature_fraction=0.9, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=500, num_leaves=50, reg_alpha=0.1, reg_lambda=0.1; total time=   7.2s
# [CV] END bagging_fraction=0.8, bagging_freq=0, feature_fraction=1.0, learning_rate=0.05, max_depth=-1, min_child_samples=10, n_estimators=500, num_leaves=31, reg_alpha=0, reg_lambda=0.5; total time=  15.8s
# [CV] END bagging_fraction=1.0, bagging_freq=0, feature_fraction=0.9, learning_rate=0.1, max_depth=5, min_child_samples=30, n_estimators=500, num_leaves=50, reg_alpha=0.1, reg_lambda=0.1; total time=   8.7s
# [CV] END bagging_fraction=0.8, bagging_freq=0, feature_fraction=1.0, learning_rate=0.05, max_depth=-1, min_child_samples=10, n_estimators=500, num_leaves=31, reg_alpha=0, reg_lambda=0.5; total time=  15.6s
# [CV] END bagging_fraction=0.9, bagging_freq=10, feature_fraction=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=50, n_estimators=100, num_leaves=31, reg_alpha=0, reg_lambda=0.1; total time=   2.6s
# [CV] END bagging_fraction=0.9, bagging_freq=10, feature_fraction=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=50, n_estimators=100, num_leaves=31, reg_alpha=0, reg_lambda=0.1; total time=   2.6s
# [CV] END bagging_fraction=0.8, bagging_freq=5, feature_fraction=0.8, learning_rate=0.01, max_depth=20, min_child_samples=20, n_estimators=100, num_leaves=200, reg_alpha=0.1, reg_lambda=0; total time=  12.1s
# [CV] END bagging_fraction=0.9, bagging_freq=10, feature_fraction=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=50, n_estimators=100, num_leaves=31, reg_alpha=0, reg_lambda=0.1; total time=   3.0s
# [CV] END bagging_fraction=0.9, bagging_freq=10, feature_fraction=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=50, n_estimators=100, num_leaves=31, reg_alpha=0, reg_lambda=0.1; total time=   2.9s
# [CV] END bagging_fraction=0.9, bagging_freq=10, feature_fraction=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=50, n_estimators=100, num_leaves=31, reg_alpha=0, reg_lambda=0.1; total time=   2.8s
# [CV] END bagging_fraction=0.8, bagging_freq=5, feature_fraction=0.8, learning_rate=0.01, max_depth=20, min_child_samples=20, n_estimators=100, num_leaves=200, reg_alpha=0.1, reg_lambda=0; total time=  12.3s
# [CV] END bagging_fraction=0.8, bagging_freq=5, feature_fraction=0.8, learning_rate=0.01, max_depth=20, min_child_samples=20, n_estimators=100, num_leaves=200, reg_alpha=0.1, reg_lambda=0; total time=  12.5s
# [CV] END bagging_fraction=0.8, bagging_freq=5, feature_fraction=0.8, learning_rate=0.01, max_depth=20, min_child_samples=20, n_estimators=100, num_leaves=200, reg_alpha=0.1, reg_lambda=0; total time=  12.5s
# [CV] END bagging_fraction=0.8, bagging_freq=5, feature_fraction=0.8, learning_rate=0.01, max_depth=20, min_child_samples=20, n_estimators=100, num_leaves=200, reg_alpha=0.1, reg_lambda=0; total time=  12.8s
# [CV] END bagging_fraction=1.0, bagging_freq=0, feature_fraction=0.9, learning_rate=0.01, max_depth=10, min_child_samples=20, n_estimators=200, num_leaves=50, reg_alpha=0.1, reg_lambda=1.0; total time=   9.0s
# [CV] END bagging_fraction=1.0, bagging_freq=0, feature_fraction=0.9, learning_rate=0.01, max_depth=10, min_child_samples=20, n_estimators=200, num_leaves=50, reg_alpha=0.1, reg_lambda=1.0; total time=   8.8s
# [CV] END bagging_fraction=1.0, bagging_freq=0, feature_fraction=0.9, learning_rate=0.01, max_depth=10, min_child_samples=20, n_estimators=200, num_leaves=50, reg_alpha=0.1, reg_lambda=1.0; total time=   8.9s
# [CV] END bagging_fraction=1.0, bagging_freq=0, feature_fraction=0.9, learning_rate=0.01, max_depth=10, min_child_samples=20, n_estimators=200, num_leaves=50, reg_alpha=0.1, reg_lambda=1.0; total time=   9.0s
# [CV] END bagging_fraction=1.0, bagging_freq=0, feature_fraction=0.9, learning_rate=0.01, max_depth=10, min_child_samples=20, n_estimators=200, num_leaves=50, reg_alpha=0.1, reg_lambda=1.0; total time=   9.0s
# [CV] END bagging_fraction=0.9, bagging_freq=0, feature_fraction=1.0, learning_rate=0.1, max_depth=5, min_child_samples=20, n_estimators=1000, num_leaves=100, reg_alpha=0.5, reg_lambda=1.0; total time=  16.8s
# [CV] END bagging_fraction=0.9, bagging_freq=0, feature_fraction=1.0, learning_rate=0.1, max_depth=5, min_child_samples=20, n_estimators=1000, num_leaves=100, reg_alpha=0.5, reg_lambda=1.0; total time=  16.3s
# [CV] END bagging_fraction=0.9, bagging_freq=0, feature_fraction=1.0, learning_rate=0.1, max_depth=5, min_child_samples=20, n_estimators=1000, num_leaves=100, reg_alpha=0.5, reg_lambda=1.0; total time=  16.2s
# [CV] END bagging_fraction=0.9, bagging_freq=0, feature_fraction=1.0, learning_rate=0.1, max_depth=5, min_child_samples=20, n_estimators=1000, num_leaves=100, reg_alpha=0.5, reg_lambda=1.0; total time=  16.9s
# [CV] END bagging_fraction=0.9, bagging_freq=0, feature_fraction=1.0, learning_rate=0.1, max_depth=5, min_child_samples=20, n_estimators=1000, num_leaves=100, reg_alpha=0.5, reg_lambda=1.0; total time=  18.6s
# [CV] END bagging_fraction=0.9, bagging_freq=10, feature_fraction=0.7, learning_rate=0.05, max_depth=10, min_child_samples=50, n_estimators=100, num_leaves=100, reg_alpha=0.1, reg_lambda=0.1; total time=   4.8s
# [CV] END bagging_fraction=0.9, bagging_freq=10, feature_fraction=0.7, learning_rate=0.05, max_depth=10, min_child_samples=50, n_estimators=100, num_leaves=100, reg_alpha=0.1, reg_lambda=0.1; total time=   4.4s
# [CV] END bagging_fraction=0.9, bagging_freq=10, feature_fraction=0.7, learning_rate=0.05, max_depth=10, min_child_samples=50, n_estimators=100, num_leaves=100, reg_alpha=0.1, reg_lambda=0.1; total time=   4.5s
# [CV] END bagging_fraction=0.9, bagging_freq=10, feature_fraction=0.7, learning_rate=0.05, max_depth=10, min_child_samples=50, n_estimators=100, num_leaves=100, reg_alpha=0.1, reg_lambda=0.1; total time=   4.7s
# [CV] END bagging_fraction=1.0, bagging_freq=0, feature_fraction=0.9, learning_rate=0.05, max_depth=20, min_child_samples=20, n_estimators=500, num_leaves=50, reg_alpha=1.0, reg_lambda=0.1; total time=  22.3s
# [CV] END bagging_fraction=1.0, bagging_freq=0, feature_fraction=0.9, learning_rate=0.05, max_depth=20, min_child_samples=20, n_estimators=500, num_leaves=50, reg_alpha=1.0, reg_lambda=0.1; total time=  22.5s
# [CV] END bagging_fraction=1.0, bagging_freq=0, feature_fraction=0.9, learning_rate=0.05, max_depth=20, min_child_samples=20, n_estimators=500, num_leaves=50, reg_alpha=1.0, reg_lambda=0.1; total time=  22.4s
# [CV] END bagging_fraction=0.9, bagging_freq=10, feature_fraction=0.7, learning_rate=0.05, max_depth=10, min_child_samples=50, n_estimators=100, num_leaves=100, reg_alpha=0.1, reg_lambda=0.1; total time=   4.8s
# [CV] END bagging_fraction=1.0, bagging_freq=0, feature_fraction=0.9, learning_rate=0.05, max_depth=20, min_child_samples=20, n_estimators=500, num_leaves=50, reg_alpha=1.0, reg_lambda=0.1; total time=  22.0s
# [CV] END bagging_fraction=1.0, bagging_freq=0, feature_fraction=0.9, learning_rate=0.05, max_depth=20, min_child_samples=20, n_estimators=500, num_leaves=50, reg_alpha=1.0, reg_lambda=0.1; total time=  24.5s
# [CV] END bagging_fraction=0.9, bagging_freq=10, feature_fraction=0.8, learning_rate=0.1, max_depth=5, min_child_samples=10, n_estimators=500, num_leaves=200, reg_alpha=1.0, reg_lambda=1.0; total time=   9.9s
# [CV] END bagging_fraction=0.9, bagging_freq=5, feature_fraction=0.7, learning_rate=0.01, max_depth=10, min_child_samples=20, n_estimators=500, num_leaves=31, reg_alpha=0, reg_lambda=0.1; total time=  14.2s
# [CV] END bagging_fraction=0.9, bagging_freq=5, feature_fraction=0.7, learning_rate=0.01, max_depth=10, min_child_samples=20, n_estimators=500, num_leaves=31, reg_alpha=0, reg_lambda=0.1; total time=  14.1s
# [CV] END bagging_fraction=0.9, bagging_freq=5, feature_fraction=0.7, learning_rate=0.01, max_depth=10, min_child_samples=20, n_estimators=500, num_leaves=31, reg_alpha=0, reg_lambda=0.1; total time=  14.0s
# [CV] END bagging_fraction=0.9, bagging_freq=5, feature_fraction=0.7, learning_rate=0.01, max_depth=10, min_child_samples=20, n_estimators=500, num_leaves=31, reg_alpha=0, reg_lambda=0.1; total time=  14.1s
# [CV] END bagging_fraction=0.9, bagging_freq=5, feature_fraction=0.7, learning_rate=0.01, max_depth=10, min_child_samples=20, n_estimators=500, num_leaves=31, reg_alpha=0, reg_lambda=0.1; total time=  15.7s
# [CV] END bagging_fraction=0.9, bagging_freq=10, feature_fraction=0.8, learning_rate=0.1, max_depth=5, min_child_samples=10, n_estimators=500, num_leaves=200, reg_alpha=1.0, reg_lambda=1.0; total time=   9.8s
# [CV] END bagging_fraction=0.9, bagging_freq=10, feature_fraction=0.8, learning_rate=0.1, max_depth=5, min_child_samples=10, n_estimators=500, num_leaves=200, reg_alpha=1.0, reg_lambda=1.0; total time=  10.9s
# [CV] END bagging_fraction=0.9, bagging_freq=10, feature_fraction=0.8, learning_rate=0.1, max_depth=5, min_child_samples=10, n_estimators=500, num_leaves=200, reg_alpha=1.0, reg_lambda=1.0; total time=   9.5s
# [CV] END bagging_fraction=0.9, bagging_freq=10, feature_fraction=0.8, learning_rate=0.1, max_depth=5, min_child_samples=10, n_estimators=500, num_leaves=200, reg_alpha=1.0, reg_lambda=1.0; total time=  10.1s
# [CV] END bagging_fraction=0.9, bagging_freq=5, feature_fraction=1.0, learning_rate=0.01, max_depth=10, min_child_samples=20, n_estimators=100, num_leaves=50, reg_alpha=0.1, reg_lambda=0; total time=   4.5s
# [CV] END bagging_fraction=0.9, bagging_freq=5, feature_fraction=1.0, learning_rate=0.01, max_depth=10, min_child_samples=20, n_estimators=100, num_leaves=50, reg_alpha=0.1, reg_lambda=0; total time=   4.4s
# [CV] END bagging_fraction=0.9, bagging_freq=5, feature_fraction=1.0, learning_rate=0.01, max_depth=10, min_child_samples=20, n_estimators=100, num_leaves=50, reg_alpha=0.1, reg_lambda=0; total time=   4.4s
# [CV] END bagging_fraction=0.9, bagging_freq=5, feature_fraction=1.0, learning_rate=0.01, max_depth=10, min_child_samples=20, n_estimators=100, num_leaves=50, reg_alpha=0.1, reg_lambda=0; total time=   4.1s
# [CV] END bagging_fraction=0.9, bagging_freq=5, feature_fraction=1.0, learning_rate=0.01, max_depth=10, min_child_samples=20, n_estimators=100, num_leaves=50, reg_alpha=0.1, reg_lambda=0; total time=   4.3s
# [CV] END bagging_fraction=0.9, bagging_freq=5, feature_fraction=0.8, learning_rate=0.05, max_depth=5, min_child_samples=10, n_estimators=500, num_leaves=100, reg_alpha=0, reg_lambda=0; total time=   9.4s
# [CV] END bagging_fraction=0.8, bagging_freq=10, feature_fraction=0.7, learning_rate=0.05, max_depth=-1, min_child_samples=50, n_estimators=500, num_leaves=200, reg_alpha=0.5, reg_lambda=1.0; total time=  25.2s
# [CV] END bagging_fraction=0.9, bagging_freq=5, feature_fraction=0.8, learning_rate=0.05, max_depth=5, min_child_samples=10, n_estimators=500, num_leaves=100, reg_alpha=0, reg_lambda=0; total time=   9.5s
# [CV] END bagging_fraction=0.8, bagging_freq=10, feature_fraction=0.7, learning_rate=0.05, max_depth=-1, min_child_samples=50, n_estimators=500, num_leaves=200, reg_alpha=0.5, reg_lambda=1.0; total time=  25.4s
# [CV] END bagging_fraction=0.9, bagging_freq=5, feature_fraction=0.8, learning_rate=0.05, max_depth=5, min_child_samples=10, n_estimators=500, num_leaves=100, reg_alpha=0, reg_lambda=0; total time=   9.7s
# [CV] END bagging_fraction=0.8, bagging_freq=10, feature_fraction=0.7, learning_rate=0.05, max_depth=-1, min_child_samples=50, n_estimators=500, num_leaves=200, reg_alpha=0.5, reg_lambda=1.0; total time=  27.4s
# [CV] END bagging_fraction=0.8, bagging_freq=10, feature_fraction=0.7, learning_rate=0.05, max_depth=-1, min_child_samples=50, n_estimators=500, num_leaves=200, reg_alpha=0.5, reg_lambda=1.0; total time=  27.1s
# [CV] END bagging_fraction=0.8, bagging_freq=10, feature_fraction=0.7, learning_rate=0.05, max_depth=-1, min_child_samples=50, n_estimators=500, num_leaves=200, reg_alpha=0.5, reg_lambda=1.0; total time=  25.3s
# [CV] END bagging_fraction=0.9, bagging_freq=5, feature_fraction=0.8, learning_rate=0.05, max_depth=5, min_child_samples=10, n_estimators=500, num_leaves=100, reg_alpha=0, reg_lambda=0; total time=   9.6s
# [CV] END bagging_fraction=0.9, bagging_freq=5, feature_fraction=0.8, learning_rate=0.05, max_depth=5, min_child_samples=10, n_estimators=500, num_leaves=100, reg_alpha=0, reg_lambda=0; total time=  11.3s
# [CV] END bagging_fraction=1.0, bagging_freq=5, feature_fraction=0.7, learning_rate=0.01, max_depth=20, min_child_samples=20, n_estimators=100, num_leaves=200, reg_alpha=0.5, reg_lambda=0.1; total time=  15.2s
# [CV] END bagging_fraction=1.0, bagging_freq=5, feature_fraction=0.7, learning_rate=0.01, max_depth=20, min_child_samples=20, n_estimators=100, num_leaves=200, reg_alpha=0.5, reg_lambda=0.1; total time=  15.0s
# [CV] END bagging_fraction=1.0, bagging_freq=5, feature_fraction=0.7, learning_rate=0.01, max_depth=20, min_child_samples=20, n_estimators=100, num_leaves=200, reg_alpha=0.5, reg_lambda=0.1; total time=  15.3s
# [CV] END bagging_fraction=0.9, bagging_freq=0, feature_fraction=1.0, learning_rate=0.01, max_depth=-1, min_child_samples=20, n_estimators=1000, num_leaves=31, reg_alpha=0.5, reg_lambda=1.0; total time=  28.1s
# [CV] END bagging_fraction=0.9, bagging_freq=0, feature_fraction=1.0, learning_rate=0.01, max_depth=-1, min_child_samples=20, n_estimators=1000, num_leaves=31, reg_alpha=0.5, reg_lambda=1.0; total time=  28.2s
# [CV] END bagging_fraction=0.9, bagging_freq=0, feature_fraction=1.0, learning_rate=0.01, max_depth=-1, min_child_samples=20, n_estimators=1000, num_leaves=31, reg_alpha=0.5, reg_lambda=1.0; total time=  27.9s
# [CV] END bagging_fraction=0.9, bagging_freq=0, feature_fraction=1.0, learning_rate=0.01, max_depth=-1, min_child_samples=20, n_estimators=1000, num_leaves=31, reg_alpha=0.5, reg_lambda=1.0; total time=  28.2s
# [CV] END bagging_fraction=1.0, bagging_freq=10, feature_fraction=0.9, learning_rate=0.05, max_depth=-1, min_child_samples=10, n_estimators=100, num_leaves=50, reg_alpha=0.1, reg_lambda=0.1; total time=   5.0s
# [CV] END bagging_fraction=1.0, bagging_freq=10, feature_fraction=0.9, learning_rate=0.05, max_depth=-1, min_child_samples=10, n_estimators=100, num_leaves=50, reg_alpha=0.1, reg_lambda=0.1; total time=   4.6s
# [CV] END bagging_fraction=1.0, bagging_freq=10, feature_fraction=0.9, learning_rate=0.05, max_depth=-1, min_child_samples=10, n_estimators=100, num_leaves=50, reg_alpha=0.1, reg_lambda=0.1; total time=   5.1s
# [CV] END bagging_fraction=1.0, bagging_freq=10, feature_fraction=0.9, learning_rate=0.05, max_depth=-1, min_child_samples=10, n_estimators=100, num_leaves=50, reg_alpha=0.1, reg_lambda=0.1; total time=   4.4s
# [CV] END bagging_fraction=1.0, bagging_freq=10, feature_fraction=0.9, learning_rate=0.05, max_depth=-1, min_child_samples=10, n_estimators=100, num_leaves=50, reg_alpha=0.1, reg_lambda=0.1; total time=   4.7s
# [CV] END bagging_fraction=0.9, bagging_freq=0, feature_fraction=1.0, learning_rate=0.01, max_depth=-1, min_child_samples=20, n_estimators=1000, num_leaves=31, reg_alpha=0.5, reg_lambda=1.0; total time=  31.8s
# [CV] END bagging_fraction=1.0, bagging_freq=5, feature_fraction=0.7, learning_rate=0.01, max_depth=20, min_child_samples=20, n_estimators=100, num_leaves=200, reg_alpha=0.5, reg_lambda=0.1; total time=  15.6s
# [CV] END bagging_fraction=1.0, bagging_freq=5, feature_fraction=0.7, learning_rate=0.01, max_depth=20, min_child_samples=20, n_estimators=100, num_leaves=200, reg_alpha=0.5, reg_lambda=0.1; total time=  15.7s
# [CV] END bagging_fraction=1.0, bagging_freq=5, feature_fraction=1.0, learning_rate=0.1, max_depth=20, min_child_samples=30, n_estimators=100, num_leaves=200, reg_alpha=0, reg_lambda=0; total time=  10.4s
# [CV] END bagging_fraction=1.0, bagging_freq=5, feature_fraction=1.0, learning_rate=0.1, max_depth=20, min_child_samples=30, n_estimators=100, num_leaves=200, reg_alpha=0, reg_lambda=0; total time=  10.4s
# [CV] END bagging_fraction=1.0, bagging_freq=5, feature_fraction=1.0, learning_rate=0.1, max_depth=20, min_child_samples=30, n_estimators=100, num_leaves=200, reg_alpha=0, reg_lambda=0; total time=  10.8s
# [CV] END bagging_fraction=0.9, bagging_freq=0, feature_fraction=0.7, learning_rate=0.1, max_depth=5, min_child_samples=10, n_estimators=100, num_leaves=200, reg_alpha=0.5, reg_lambda=0.5; total time=   1.7s
# [CV] END bagging_fraction=0.9, bagging_freq=0, feature_fraction=0.7, learning_rate=0.1, max_depth=5, min_child_samples=10, n_estimators=100, num_leaves=200, reg_alpha=0.5, reg_lambda=0.5; total time=   1.8s
# [CV] END bagging_fraction=0.9, bagging_freq=0, feature_fraction=0.7, learning_rate=0.1, max_depth=5, min_child_samples=10, n_estimators=100, num_leaves=200, reg_alpha=0.5, reg_lambda=0.5; total time=   1.7s
# [CV] END bagging_fraction=0.9, bagging_freq=0, feature_fraction=0.7, learning_rate=0.1, max_depth=5, min_child_samples=10, n_estimators=100, num_leaves=200, reg_alpha=0.5, reg_lambda=0.5; total time=   1.7s
# [CV] END bagging_fraction=1.0, bagging_freq=5, feature_fraction=1.0, learning_rate=0.1, max_depth=20, min_child_samples=30, n_estimators=100, num_leaves=200, reg_alpha=0, reg_lambda=0; total time=  10.6s
# [CV] END bagging_fraction=0.9, bagging_freq=0, feature_fraction=0.7, learning_rate=0.1, max_depth=5, min_child_samples=10, n_estimators=100, num_leaves=200, reg_alpha=0.5, reg_lambda=0.5; total time=   2.1s
# [CV] END bagging_fraction=1.0, bagging_freq=5, feature_fraction=1.0, learning_rate=0.1, max_depth=20, min_child_samples=30, n_estimators=100, num_leaves=200, reg_alpha=0, reg_lambda=0; total time=  10.1s
# [CV] END bagging_fraction=0.9, bagging_freq=10, feature_fraction=0.8, learning_rate=0.01, max_depth=-1, min_child_samples=30, n_estimators=1000, num_leaves=100, reg_alpha=0.5, reg_lambda=1.0; total time= 1.4min
# [CV] END bagging_fraction=0.9, bagging_freq=10, feature_fraction=0.8, learning_rate=0.01, max_depth=-1, min_child_samples=30, n_estimators=1000, num_leaves=100, reg_alpha=0.5, reg_lambda=1.0; total time= 1.4min
# [CV] END bagging_fraction=0.9, bagging_freq=10, feature_fraction=0.8, learning_rate=0.01, max_depth=-1, min_child_samples=30, n_estimators=1000, num_leaves=100, reg_alpha=0.5, reg_lambda=1.0; total time= 1.4min
# [CV] END bagging_fraction=0.9, bagging_freq=10, feature_fraction=0.8, learning_rate=0.01, max_depth=-1, min_child_samples=30, n_estimators=1000, num_leaves=100, reg_alpha=0.5, reg_lambda=1.0; total time= 1.4min
# [CV] END bagging_fraction=0.9, bagging_freq=10, feature_fraction=0.8, learning_rate=0.01, max_depth=-1, min_child_samples=30, n_estimators=1000, num_leaves=100, reg_alpha=0.5, reg_lambda=1.0; total time= 1.4min
# [CV] END bagging_fraction=1.0, bagging_freq=5, feature_fraction=0.7, learning_rate=0.01, max_depth=10, min_child_samples=20, n_estimators=1000, num_leaves=200, reg_alpha=1.0, reg_lambda=0.5; total time= 1.1min
# [CV] END bagging_fraction=1.0, bagging_freq=5, feature_fraction=0.7, learning_rate=0.01, max_depth=10, min_child_samples=20, n_estimators=1000, num_leaves=200, reg_alpha=1.0, reg_lambda=0.5; total time= 1.2min
# [CV] END bagging_fraction=1.0, bagging_freq=5, feature_fraction=0.7, learning_rate=0.01, max_depth=10, min_child_samples=20, n_estimators=1000, num_leaves=200, reg_alpha=1.0, reg_lambda=0.5; total time= 1.2min
# [CV] END bagging_fraction=0.9, bagging_freq=0, feature_fraction=0.7, learning_rate=0.01, max_depth=5, min_child_samples=50, n_estimators=1000, num_leaves=200, reg_alpha=1.0, reg_lambda=1.0; total time=  12.9s
# [CV] END bagging_fraction=0.9, bagging_freq=0, feature_fraction=0.7, learning_rate=0.01, max_depth=5, min_child_samples=50, n_estimators=1000, num_leaves=200, reg_alpha=1.0, reg_lambda=1.0; total time=  12.8s
# [CV] END bagging_fraction=1.0, bagging_freq=5, feature_fraction=1.0, learning_rate=0.01, max_depth=20, min_child_samples=30, n_estimators=500, num_leaves=100, reg_alpha=0.5, reg_lambda=0.1; total time=  40.9s
# [CV] END bagging_fraction=1.0, bagging_freq=5, feature_fraction=1.0, learning_rate=0.01, max_depth=20, min_child_samples=30, n_estimators=500, num_leaves=100, reg_alpha=0.5, reg_lambda=0.1; total time=  41.2s
# [CV] END bagging_fraction=1.0, bagging_freq=5, feature_fraction=1.0, learning_rate=0.01, max_depth=20, min_child_samples=30, n_estimators=500, num_leaves=100, reg_alpha=0.5, reg_lambda=0.1; total time=  40.9s
# [CV] END bagging_fraction=1.0, bagging_freq=5, feature_fraction=1.0, learning_rate=0.01, max_depth=20, min_child_samples=30, n_estimators=500, num_leaves=100, reg_alpha=0.5, reg_lambda=0.1; total time=  41.0s
# [CV] END bagging_fraction=0.9, bagging_freq=0, feature_fraction=0.7, learning_rate=0.01, max_depth=5, min_child_samples=50, n_estimators=1000, num_leaves=200, reg_alpha=1.0, reg_lambda=1.0; total time=  13.7s
# [CV] END bagging_fraction=1.0, bagging_freq=5, feature_fraction=1.0, learning_rate=0.01, max_depth=20, min_child_samples=30, n_estimators=500, num_leaves=100, reg_alpha=0.5, reg_lambda=0.1; total time=  41.1s
# [CV] END bagging_fraction=0.9, bagging_freq=0, feature_fraction=0.7, learning_rate=0.01, max_depth=5, min_child_samples=50, n_estimators=1000, num_leaves=200, reg_alpha=1.0, reg_lambda=1.0; total time=  13.5s
# [CV] END bagging_fraction=0.9, bagging_freq=0, feature_fraction=0.7, learning_rate=0.01, max_depth=5, min_child_samples=50, n_estimators=1000, num_leaves=200, reg_alpha=1.0, reg_lambda=1.0; total time=  14.7s
# [CV] END bagging_fraction=1.0, bagging_freq=5, feature_fraction=0.7, learning_rate=0.01, max_depth=10, min_child_samples=20, n_estimators=1000, num_leaves=200, reg_alpha=1.0, reg_lambda=0.5; total time= 1.2min
# [CV] END bagging_fraction=1.0, bagging_freq=5, feature_fraction=0.7, learning_rate=0.01, max_depth=10, min_child_samples=20, n_estimators=1000, num_leaves=200, reg_alpha=1.0, reg_lambda=0.5; total time= 1.3min
# [CV] END bagging_fraction=0.8, bagging_freq=10, feature_fraction=0.9, learning_rate=0.05, max_depth=20, min_child_samples=20, n_estimators=1000, num_leaves=50, reg_alpha=0.5, reg_lambda=1.0; total time=  47.9s
# [CV] END bagging_fraction=0.8, bagging_freq=0, feature_fraction=0.7, learning_rate=0.01, max_depth=10, min_child_samples=30, n_estimators=500, num_leaves=200, reg_alpha=0.5, reg_lambda=1.0; total time=  38.2s
# [CV] END bagging_fraction=0.8, bagging_freq=10, feature_fraction=0.9, learning_rate=0.05, max_depth=20, min_child_samples=20, n_estimators=1000, num_leaves=50, reg_alpha=0.5, reg_lambda=1.0; total time=  49.8s
# [CV] END bagging_fraction=0.8, bagging_freq=10, feature_fraction=0.9, learning_rate=0.05, max_depth=20, min_child_samples=20, n_estimators=1000, num_leaves=50, reg_alpha=0.5, reg_lambda=1.0; total time=  49.7s
# [CV] END bagging_fraction=0.8, bagging_freq=10, feature_fraction=0.9, learning_rate=0.05, max_depth=20, min_child_samples=20, n_estimators=1000, num_leaves=50, reg_alpha=0.5, reg_lambda=1.0; total time=  49.0s
# [CV] END bagging_fraction=0.8, bagging_freq=0, feature_fraction=0.7, learning_rate=0.01, max_depth=10, min_child_samples=30, n_estimators=500, num_leaves=200, reg_alpha=0.5, reg_lambda=1.0; total time=  38.9s
# [CV] END bagging_fraction=0.8, bagging_freq=10, feature_fraction=0.9, learning_rate=0.05, max_depth=20, min_child_samples=20, n_estimators=1000, num_leaves=50, reg_alpha=0.5, reg_lambda=1.0; total time=  54.5s
# [CV] END bagging_fraction=0.8, bagging_freq=0, feature_fraction=0.7, learning_rate=0.01, max_depth=10, min_child_samples=30, n_estimators=500, num_leaves=200, reg_alpha=0.5, reg_lambda=1.0; total time=  39.0s
# [CV] END bagging_fraction=0.8, bagging_freq=0, feature_fraction=0.7, learning_rate=0.01, max_depth=10, min_child_samples=30, n_estimators=500, num_leaves=200, reg_alpha=0.5, reg_lambda=1.0; total time=  40.1s
# [CV] END bagging_fraction=0.8, bagging_freq=10, feature_fraction=0.9, learning_rate=0.01, max_depth=-1, min_child_samples=50, n_estimators=1000, num_leaves=31, reg_alpha=1.0, reg_lambda=1.0; total time=  31.2s
# [CV] END bagging_fraction=0.8, bagging_freq=0, feature_fraction=0.7, learning_rate=0.01, max_depth=10, min_child_samples=30, n_estimators=500, num_leaves=200, reg_alpha=0.5, reg_lambda=1.0; total time=  40.5s
# [CV] END bagging_fraction=0.8, bagging_freq=10, feature_fraction=0.9, learning_rate=0.01, max_depth=-1, min_child_samples=50, n_estimators=1000, num_leaves=31, reg_alpha=1.0, reg_lambda=1.0; total time=  34.0s
# [CV] END bagging_fraction=0.8, bagging_freq=10, feature_fraction=0.9, learning_rate=0.01, max_depth=-1, min_child_samples=50, n_estimators=1000, num_leaves=31, reg_alpha=1.0, reg_lambda=1.0; total time=  30.4s
# [CV] END bagging_fraction=0.8, bagging_freq=10, feature_fraction=0.9, learning_rate=0.01, max_depth=-1, min_child_samples=50, n_estimators=1000, num_leaves=31, reg_alpha=1.0, reg_lambda=1.0; total time=  35.4s
# [CV] END bagging_fraction=0.8, bagging_freq=10, feature_fraction=0.9, learning_rate=0.01, max_depth=-1, min_child_samples=50, n_estimators=1000, num_leaves=31, reg_alpha=1.0, reg_lambda=1.0; total time=  35.2s
# [CV] END bagging_fraction=0.8, bagging_freq=10, feature_fraction=0.9, learning_rate=0.05, max_depth=10, min_child_samples=50, n_estimators=500, num_leaves=200, reg_alpha=1.0, reg_lambda=0.1; total time=  22.9s
# [CV] END bagging_fraction=0.8, bagging_freq=10, feature_fraction=0.9, learning_rate=0.05, max_depth=10, min_child_samples=50, n_estimators=500, num_leaves=200, reg_alpha=1.0, reg_lambda=0.1; total time=  24.6s
# [CV] END bagging_fraction=0.8, bagging_freq=10, feature_fraction=0.9, learning_rate=0.05, max_depth=10, min_child_samples=50, n_estimators=500, num_leaves=200, reg_alpha=1.0, reg_lambda=0.1; total time=  21.9s
# [CV] END bagging_fraction=0.8, bagging_freq=10, feature_fraction=0.9, learning_rate=0.05, max_depth=10, min_child_samples=50, n_estimators=500, num_leaves=200, reg_alpha=1.0, reg_lambda=0.1; total time=  21.6s
# [CV] END bagging_fraction=0.8, bagging_freq=10, feature_fraction=0.9, learning_rate=0.05, max_depth=10, min_child_samples=50, n_estimators=500, num_leaves=200, reg_alpha=1.0, reg_lambda=0.1; total time=  22.8s
# [CV] END bagging_fraction=0.8, bagging_freq=5, feature_fraction=0.9, learning_rate=0.1, max_depth=10, min_child_samples=30, n_estimators=500, num_leaves=100, reg_alpha=1.0, reg_lambda=0.5; total time=  29.6s
# [CV] END bagging_fraction=0.8, bagging_freq=5, feature_fraction=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=10, n_estimators=500, num_leaves=200, reg_alpha=1.0, reg_lambda=0.1; total time= 1.6min
# [CV] END bagging_fraction=0.8, bagging_freq=5, feature_fraction=0.9, learning_rate=0.1, max_depth=10, min_child_samples=30, n_estimators=500, num_leaves=100, reg_alpha=1.0, reg_lambda=0.5; total time=  32.1s
# [CV] END bagging_fraction=0.8, bagging_freq=5, feature_fraction=0.9, learning_rate=0.1, max_depth=10, min_child_samples=30, n_estimators=500, num_leaves=100, reg_alpha=1.0, reg_lambda=0.5; total time=  32.9s
# [CV] END bagging_fraction=0.8, bagging_freq=5, feature_fraction=0.9, learning_rate=0.1, max_depth=10, min_child_samples=30, n_estimators=500, num_leaves=100, reg_alpha=1.0, reg_lambda=0.5; total time=  35.0s
# [CV] END bagging_fraction=0.8, bagging_freq=5, feature_fraction=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=10, n_estimators=500, num_leaves=200, reg_alpha=1.0, reg_lambda=0.1; total time= 1.7min
# [CV] END bagging_fraction=0.8, bagging_freq=5, feature_fraction=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=10, n_estimators=500, num_leaves=200, reg_alpha=1.0, reg_lambda=0.1; total time= 1.7min
# [CV] END bagging_fraction=1.0, bagging_freq=10, feature_fraction=0.9, learning_rate=0.1, max_depth=10, min_child_samples=50, n_estimators=500, num_leaves=200, reg_alpha=1.0, reg_lambda=0.1; total time=  19.9s
# [CV] END bagging_fraction=0.8, bagging_freq=5, feature_fraction=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=10, n_estimators=500, num_leaves=200, reg_alpha=1.0, reg_lambda=0.1; total time= 1.7min
# [CV] END bagging_fraction=0.8, bagging_freq=5, feature_fraction=0.8, learning_rate=0.05, max_depth=-1, min_child_samples=10, n_estimators=500, num_leaves=200, reg_alpha=1.0, reg_lambda=0.1; total time= 1.7min
# [CV] END bagging_fraction=1.0, bagging_freq=10, feature_fraction=0.9, learning_rate=0.1, max_depth=10, min_child_samples=50, n_estimators=500, num_leaves=200, reg_alpha=1.0, reg_lambda=0.1; total time=  21.0s
# [CV] END bagging_fraction=1.0, bagging_freq=5, feature_fraction=1.0, learning_rate=0.01, max_depth=-1, min_child_samples=30, n_estimators=100, num_leaves=200, reg_alpha=0, reg_lambda=0.5; total time=  11.7s
# [CV] END bagging_fraction=0.8, bagging_freq=5, feature_fraction=0.9, learning_rate=0.1, max_depth=10, min_child_samples=30, n_estimators=500, num_leaves=100, reg_alpha=1.0, reg_lambda=0.5; total time=  36.4s
# [CV] END bagging_fraction=1.0, bagging_freq=5, feature_fraction=1.0, learning_rate=0.01, max_depth=-1, min_child_samples=30, n_estimators=100, num_leaves=200, reg_alpha=0, reg_lambda=0.5; total time=  14.3s
# [CV] END bagging_fraction=1.0, bagging_freq=5, feature_fraction=1.0, learning_rate=0.01, max_depth=-1, min_child_samples=30, n_estimators=100, num_leaves=200, reg_alpha=0, reg_lambda=0.5; total time=  13.5s
# [CV] END bagging_fraction=1.0, bagging_freq=10, feature_fraction=0.9, learning_rate=0.1, max_depth=10, min_child_samples=50, n_estimators=500, num_leaves=200, reg_alpha=1.0, reg_lambda=0.1; total time=  21.7s
# [CV] END bagging_fraction=0.8, bagging_freq=5, feature_fraction=0.8, learning_rate=0.05, max_depth=5, min_child_samples=50, n_estimators=200, num_leaves=100, reg_alpha=0.5, reg_lambda=1.0; total time=   4.3s
# [CV] END bagging_fraction=1.0, bagging_freq=5, feature_fraction=1.0, learning_rate=0.01, max_depth=-1, min_child_samples=30, n_estimators=100, num_leaves=200, reg_alpha=0, reg_lambda=0.5; total time=  14.4s
# [CV] END bagging_fraction=1.0, bagging_freq=10, feature_fraction=0.9, learning_rate=0.1, max_depth=10, min_child_samples=50, n_estimators=500, num_leaves=200, reg_alpha=1.0, reg_lambda=0.1; total time=  22.9s
# [CV] END bagging_fraction=0.8, bagging_freq=5, feature_fraction=0.8, learning_rate=0.05, max_depth=5, min_child_samples=50, n_estimators=200, num_leaves=100, reg_alpha=0.5, reg_lambda=1.0; total time=   4.0s
# [CV] END bagging_fraction=0.8, bagging_freq=5, feature_fraction=0.8, learning_rate=0.05, max_depth=5, min_child_samples=50, n_estimators=200, num_leaves=100, reg_alpha=0.5, reg_lambda=1.0; total time=   3.6s
# [CV] END bagging_fraction=0.8, bagging_freq=5, feature_fraction=0.8, learning_rate=0.05, max_depth=5, min_child_samples=50, n_estimators=200, num_leaves=100, reg_alpha=0.5, reg_lambda=1.0; total time=   3.9s
# [CV] END bagging_fraction=0.8, bagging_freq=5, feature_fraction=0.8, learning_rate=0.05, max_depth=5, min_child_samples=50, n_estimators=200, num_leaves=100, reg_alpha=0.5, reg_lambda=1.0; total time=   4.1s
# [CV] END bagging_fraction=1.0, bagging_freq=10, feature_fraction=0.9, learning_rate=0.1, max_depth=10, min_child_samples=50, n_estimators=500, num_leaves=200, reg_alpha=1.0, reg_lambda=0.1; total time=  25.1s
# [CV] END bagging_fraction=1.0, bagging_freq=5, feature_fraction=1.0, learning_rate=0.01, max_depth=-1, min_child_samples=30, n_estimators=100, num_leaves=200, reg_alpha=0, reg_lambda=0.5; total time=  15.4s
# [CV] END bagging_fraction=1.0, bagging_freq=0, feature_fraction=0.8, learning_rate=0.1, max_depth=20, min_child_samples=30, n_estimators=100, num_leaves=200, reg_alpha=0.1, reg_lambda=0.5; total time=  18.5s
# [CV] END bagging_fraction=1.0, bagging_freq=0, feature_fraction=0.8, learning_rate=0.1, max_depth=20, min_child_samples=30, n_estimators=100, num_leaves=200, reg_alpha=0.1, reg_lambda=0.5; total time=  18.9s
# [CV] END bagging_fraction=1.0, bagging_freq=0, feature_fraction=0.8, learning_rate=0.1, max_depth=20, min_child_samples=30, n_estimators=100, num_leaves=200, reg_alpha=0.1, reg_lambda=0.5; total time=  19.6s
# [CV] END bagging_fraction=1.0, bagging_freq=0, feature_fraction=0.8, learning_rate=0.1, max_depth=20, min_child_samples=30, n_estimators=100, num_leaves=200, reg_alpha=0.1, reg_lambda=0.5; total time=  19.3s
# [CV] END bagging_fraction=1.0, bagging_freq=0, feature_fraction=0.8, learning_rate=0.1, max_depth=20, min_child_samples=30, n_estimators=100, num_leaves=200, reg_alpha=0.1, reg_lambda=0.5; total time=  19.7s
# [CV] END bagging_fraction=1.0, bagging_freq=0, feature_fraction=0.9, learning_rate=0.1, max_depth=5, min_child_samples=10, n_estimators=1000, num_leaves=200, reg_alpha=0, reg_lambda=1.0; total time=  27.4s
# [CV] END bagging_fraction=1.0, bagging_freq=0, feature_fraction=0.9, learning_rate=0.1, max_depth=5, min_child_samples=10, n_estimators=1000, num_leaves=200, reg_alpha=0, reg_lambda=1.0; total time=  27.5s
# [CV] END bagging_fraction=1.0, bagging_freq=0, feature_fraction=0.9, learning_rate=0.1, max_depth=5, min_child_samples=10, n_estimators=1000, num_leaves=200, reg_alpha=0, reg_lambda=1.0; total time=  26.4s
# [CV] END bagging_fraction=1.0, bagging_freq=0, feature_fraction=0.9, learning_rate=0.1, max_depth=5, min_child_samples=10, n_estimators=1000, num_leaves=200, reg_alpha=0, reg_lambda=1.0; total time=  17.4s
# [CV] END bagging_fraction=1.0, bagging_freq=0, feature_fraction=0.9, learning_rate=0.1, max_depth=5, min_child_samples=10, n_estimators=1000, num_leaves=200, reg_alpha=0, reg_lambda=1.0; total time=  16.1s
# 2025-04-03 21:21:46,082 - src.trainer.train_lgbm - INFO - Best params: {'reg_lambda': 1.0, 'reg_alpha': 1.0, 'num_leaves': 200, 'n_estimators': 1000, 'min_child_samples': 50, 'max_depth': 5, 'learning_rate': 0.01, 'feature_fraction': 0.7, 'bagging_freq': 0, 'bagging_fraction': 0.9}
# 2025-04-03 21:21:46,085 - src.trainer.train_lgbm - INFO - Best cross-validation RMSE: 224.3951

# %%
lgbm_trainer.plot_actual_vs_predicted(
    output_path=config.results_figs_dir / "actual_vs_predicted.png"
)

# %%
lgbm_trainer.plot_feature_importance(
    output_path=config.results_figs_dir / "feature_importance.png"
)

# %%
lgbm_trainer.plot_shap_values(output_path=config.results_figs_dir / "shap_values.png")
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var t={221:(t,n,e)=>{"use strict";var r=e(540);function i(t){var n="https://react.dev/errors/"+t;if(1<arguments.length){n+="?args[]="+encodeURIComponent(arguments[1]);for(var e=2;e<arguments.length;e++)n+="&args[]="+encodeURIComponent(arguments[e])}return"Minified React error #"+t+"; visit "+n+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function o(){}var u={d:{f:o,r:function(){throw Error(i(522))},D:o,C:o,L:o,m:o,X:o,S:o,M:o},p:0,findDOMNode:null},a=Symbol.for("react.portal"),c=r.__CLIENT_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE;function s(t,n){return"font"===t?"":"string"==typeof n?"use-credentials"===n?n:"":void 0}n.__DOM_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE=u,n.createPortal=function(t,n){var e=2<arguments.length&&void 0!==arguments[2]?arguments[2]:null;if(!n||1!==n.nodeType&&9!==n.nodeType&&11!==n.nodeType)throw Error(i(299));return function(t,n,e){var r=3<arguments.length&&void 0!==arguments[3]?arguments[3]:null;return{$$typeof:a,key:null==r?null:""+r,children:t,containerInfo:n,implementation:e}}(t,n,null,e)},n.flushSync=function(t){var n=c.T,e=u.p;try{if(c.T=null,u.p=2,t)return t()}finally{c.T=n,u.p=e,u.d.f()}},n.preconnect=function(t,n){"string"==typeof t&&(n=n?"string"==typeof(n=n.crossOrigin)?"use-credentials"===n?n:"":void 0:null,u.d.C(t,n))},n.prefetchDNS=function(t){"string"==typeof t&&u.d.D(t)},n.preinit=function(t,n){if("string"==typeof t&&n&&"string"==typeof n.as){var e=n.as,r=s(e,n.crossOrigin),i="string"==typeof n.integrity?n.integrity:void 0,o="string"==typeof n.fetchPriority?n.fetchPriority:void 0;"style"===e?u.d.S(t,"string"==typeof n.precedence?n.precedence:void 0,{crossOrigin:r,integrity:i,fetchPriority:o}):"script"===e&&u.d.X(t,{crossOrigin:r,integrity:i,fetchPriority:o,nonce:"string"==typeof n.nonce?n.nonce:void 0})}},n.preinitModule=function(t,n){if("string"==typeof t)if("object"==typeof n&&null!==n){if(null==n.as||"script"===n.as){var e=s(n.as,n.crossOrigin);u.d.M(t,{crossOrigin:e,integrity:"string"==typeof n.integrity?n.integrity:void 0,nonce:"string"==typeof n.nonce?n.nonce:void 0})}}else null==n&&u.d.M(t)},n.preload=function(t,n){if("string"==typeof t&&"object"==typeof n&&null!==n&&"string"==typeof n.as){var e=n.as,r=s(e,n.crossOrigin);u.d.L(t,e,{crossOrigin:r,integrity:"string"==typeof n.integrity?n.integrity:void 0,nonce:"string"==typeof n.nonce?n.nonce:void 0,type:"string"==typeof n.type?n.type:void 0,fetchPriority:"string"==typeof n.fetchPriority?n.fetchPriority:void 0,referrerPolicy:"string"==typeof n.referrerPolicy?n.referrerPolicy:void 0,imageSrcSet:"string"==typeof n.imageSrcSet?n.imageSrcSet:void 0,imageSizes:"string"==typeof n.imageSizes?n.imageSizes:void 0,media:"string"==typeof n.media?n.media:void 0})}},n.preloadModule=function(t,n){if("string"==typeof t)if(n){var e=s(n.as,n.crossOrigin);u.d.m(t,{as:"string"==typeof n.as&&"script"!==n.as?n.as:void 0,crossOrigin:e,integrity:"string"==typeof n.integrity?n.integrity:void 0})}else u.d.m(t)},n.requestFormReset=function(t){u.d.r(t)},n.unstable_batchedUpdates=function(t,n){return t(n)},n.useFormState=function(t,n,e){return c.H.useFormState(t,n,e)},n.useFormStatus=function(){return c.H.useHostTransitionStatus()},n.version="19.0.0"},540:(t,n,e)=>{"use strict";t.exports=e(869)},543:function(t,n,e){var r;t=e.nmd(t),function(){var i,o="Expected a function",u="__lodash_hash_undefined__",a="__lodash_placeholder__",c=32,s=128,f=1/0,l=9007199254740991,h=NaN,p=4294967295,v=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",c],["partialRight",64],["rearg",256]],d="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",_="[object Error]",x="[object Function]",b="[object GeneratorFunction]",w="[object Map]",k="[object Number]",S="[object Object]",M="[object Promise]",A="[object RegExp]",T="[object Set]",O="[object String]",j="[object Symbol]",E="[object WeakMap]",C="[object ArrayBuffer]",$= ...
