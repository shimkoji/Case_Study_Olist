# %%
# %%time
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import sys
from dataclasses import dataclass
from pathlib import Path

from dotenv import load_dotenv


@dataclass
class Config:
    project_dir: Path = Path("../")
    model_dir: Path = project_dir / "models"
    outputs_dir: Path = project_dir / "outputs"
    results_dir: Path = project_dir / "results"
    results_agg_dir: Path = results_dir / "agg"
    results_figs_dir: Path = results_dir / "figs"
    data_dir: Path = project_dir / "data"
    raw_dir: Path = data_dir / "raw"
    interim_dir: Path = data_dir / "interim"
    processed_dir: Path = data_dir / "processed"


config = Config()
sys.path.append(str(config.project_dir.resolve()))
load_dotenv()
# Out:
# CPU times: user 824 ms, sys: 157 ms, total: 981 ms
# Wall time: 3.92 s
# True

# %%
from src.data_processor.processor import Processor

processor = Processor(
    raw_data_path=config.raw_dir,
    processed_data_path=config.processed_dir,
    interim_data_path=config.interim_dir,
)

# %%
processor.merge_products_seller_data(
    output_path=config.interim_dir / "olist_item_product_seller_merged.csv"
)
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
# It takes about 6hours to finish this code
processor.process_review_data(
    output_path=config.interim_dir
    / "olist_order_reviews_translated_label_review_categories_merged.csv"
)
# Out:
# 2025-03-26 23:04:43,820 - src.data_processor.process_review_data - INFO - Translation task start
# Starting translation for 13 texts from review_comment_title
# 100%|██████████| 1/1 [00:04<00:00,  4.57s/it]
# Starting translation for 40 texts from review_comment_message
# 100%|██████████| 2/2 [00:26<00:00, 13.39s/it]
# 2025-03-26 23:05:15,258 - src.data_processor.process_review_data - INFO - Translation task end
# 2025-03-26 23:05:15,259 - src.data_processor.process_review_data - INFO - Sentiment analysis task start
# Device set to use mps:0
# 100%|██████████| 100/100 [00:02<00:00, 38.65it/s]
# 2025-03-26 23:05:19,549 - src.data_processor.process_review_data - INFO - Sentiment analysis task end
# 2025-03-26 23:05:19,549 - src.data_processor.process_review_data - INFO - Classification task start
# Starting classification for 40 reviews
# 100%|██████████| 2/2 [00:14<00:00,  7.21s/it]
# 2025-03-26 23:05:34,011 - src.data_processor.process_review_data - INFO - Classification task end

# %%
processor.merge_order_customer_data(
    output_path=config.interim_dir / "olist_orders_customer_merged.csv"
)

# %%
processor.process_order_details_data(
    output_path=config.processed_dir / "order_info_details.csv"
)
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp   order_approved_at  \
# ...
